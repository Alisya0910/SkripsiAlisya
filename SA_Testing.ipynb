# %% [markdown]
# <a href="https://colab.research.google.com/github/Alisya0910/SkripsiAlisya/blob/main/SA_Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download("vader_lexicon")
import pandas as pd
data = pd.read_excel('eng.xlsx')
data = data.dropna()
print(data.head())
# Out:
#                                                 Text
# 0  Is it true that Presidential Candidate Subiant...
# 1                            we are proud of you sir
# 2  God willing, we can... Indonesia is golden tog...
# 3               Only Pak Prabowo cares about farmers
# 4  Anies supporters won't go to Prabowo, especial...
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
sentiments = SentimentIntensityAnalyzer()
data['Positive'] = [sentiments.polarity_scores(i)["pos"] for i in data["Text"]]
data['Negative'] = [sentiments.polarity_scores(i)["neg"] for i in data["Text"]]
data['Neutral'] = [sentiments.polarity_scores(i)["neu"] for i in data["Text"]]
data['Compound'] = [sentiments.polarity_scores(i)["compound"] for i in data["Text"]]

# %%
score = data['Compound'].values
sentiment = []
for i in score:
  if i >= 0.05 :
    sentiment.append('positif')
  elif i <= -0.05 :
      sentiment.append('negatif')
  else:
      sentiment.append('netral')
data['sentiment'] = sentiment
data
# Out:
#                                                  Text  Positive  Negative  \
# 0   Is it true that Presidential Candidate Subiant...     0.237     0.000
# 1                             we are proud of you sir     0.383     0.000
# 2   God willing, we can... Indonesia is golden tog...     0.231     0.000
# 3                Only Pak Prabowo cares about farmers     0.375     0.000
# 4   Anies supporters won't go to Prabowo, especial...     0.458     0.000
# 5   Prabowo terbukti melanggar HAM berat, temperam...     0.000     0.000
# 6   How come Prabowo's supporters are as stupid as...     0.218     0.256
# 7   Bhahahaha prabowo penghianat nyet.... dia mala...     0.000     0.000
# 8                   No to Prabowo... Yes to Ganjar...     0.303     0.247
# 9   GRATEFUL because the majority of the Indonesia...     0.253     0.000
# 10  Elections must be clean and comply with the co...     0.252     0.000
# 11                   the people who love him the most     0.412     0.000
# ...

# %%
data.to_excel('sentimentanalysis.xlsx')
